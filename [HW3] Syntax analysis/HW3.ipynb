# %%
from pymystem3 import Mystem
from os import listdir

# %%
import pymorphy2
import pymorphy2_dicts_ru

# %%
pymorphy = pymorphy2.MorphAnalyzer()

# %%
def concat(lists):
    result = []
    for lst in lists:
        for elem in lst:
            result.append(elem)
    return result

# %%
# удаление из списка лемм "мусора", не имеющего характеристик:
# переносов строк, знаков препинания, иностранных слов и др.
def delete_trash_lemmas(words):
    return list(filter(lambda l: l.get('analysis') != None and len(l.get('analysis')) > 0, words))

# %%
def getPos(word):
    params = pymorphy.parse(word)[0]
    return params.tag.POS

# %%
# морфологический анализатор
mystem = Mystem()

# %%
# директория хранения текстовых файлов для тестирования
text_path = 'texts'

# считывание текстовых файлов из заданной директории в список текстов
texts = [ open(text_path + '/' + filename, 'r').read() for filename in listdir(text_path) ]

# %%
# предикат: является ли слово разделителем
def isSeparator(word):
    return word.get('analysis') == None

# получить текст слова
def getText(word):
    return word['text']

# извлечение из текста множества всех разделителей
separators = set(concat([ list(map(getText, filter(isSeparator, mystem.analyze(text)))) for text in texts ]))

# %%
# посмотрим на них
separators
# Out:
# {'\n',
#  ' ',
#  ' (',
#  ' «',
#  ' ‒ ',
#  ' –',
#  ' – ',
#  ' — ',
#  ' — «',
#  '!',
#  ') ',
#  '), ',
#  '); ',
#  ',',
#  ', ',
#  ', ‒ ',
#  ', – ',
#  ', — ',
#  '-',
#  '- ',
#  '.',
#  '. ',
#  '/',
#  '1917',
#  '1941',
#  ':\n',
#  ': ',
#  ': «',
#  '; ',
#  '?',
#  '? ',
#  '«',
#  '»',
#  '» ',
#  '» (',
#  '» ‒ ',
#  '», ',
#  '», – ',
#  '– ',
#  '…',
#  '… '}

# %%
# индексы элементов, ошибочно выбранных разделителями
excludeSeparators = set(['1917', '- ', '1941', ' ', '-'])

# разделители, завершающие простые предложения
endSeparators = separators - excludeSeparators
endSeparators
# Out:
# {'\n',
#  ' (',
#  ' «',
#  ' ‒ ',
#  ' –',
#  ' – ',
#  ' — ',
#  ' — «',
#  '!',
#  ') ',
#  '), ',
#  '); ',
#  ',',
#  ', ',
#  ', ‒ ',
#  ', – ',
#  ', — ',
#  '.',
#  '. ',
#  '/',
#  ':\n',
#  ': ',
#  ': «',
#  '; ',
#  '?',
#  '? ',
#  '«',
#  '»',
#  '» ',
#  '» (',
#  '» ‒ ',
#  '», ',
#  '», – ',
#  '– ',
#  '…',
#  '… '}

# %%
def print_group(group):
    if len(group) > 1:
        print('{', end='')

        for word in group:
            print(word, end='')

        print('}', end='')
    else:
        for word in group:
            print(word, end='')

def print_sentence(sentence):
    if isinstance(sentence, list):
        print('[', end='')

        for group in sentence:
            print_group(group)

        print(']', end='')
    else:
        print(sentence, end='')

def print_analyzed_text(text):
    for sentence in text:
        print_sentence(sentence)

# %%
for text in texts:
    # извлечение из текста списка слова со всеми характеристиками с помощью морфологического анализатора
    words = list(map(getText, mystem.analyze(text)))
    
    # список всех сегментов-предложений, полученных из обрабатываемого текста
    analyzed_text = []
    # список сегментов в рамках предложения
    sentence = []
    # список слов неразрывной синтаксической группы
    group = []
    
    i = 0
    while i < len(words):
        word = words[i]
        if word in endSeparators:
            if group != []:
                sentence.append(group)
                group = []

            if sentence != []:
                analyzed_text.append(sentence)
                sentence = []

            analyzed_text.append(word)
        elif word in separators and group == []:
            sentence.append([word])
        elif i + 2 < len(words) and words[i+1] not in endSeparators:
            if getPos(words[i]) == 'PREP' and getPos(words[i+2]) == 'NOUN':
                group = [ word, words[i+1], words[i+2] ]
                i += 2
                sentence.append(group)
                group = []
            elif getPos(words[i]) == 'ADJF' and getPos(words[i+2]) == 'NOUN':
                group = [ word, words[i+1], words[i+2] ]
                i += 2
                sentence.append(group)
                group = []
            else:
                sentence.append([word])
        else:
            sentence.append([word])
        i += 1
    else:
        if group != []:
            sentence.append(group)
        
        if sentence != []:
            analyzed_text.append(sentence)
    
    print_analyzed_text(analyzed_text)
# Out:
# [{Профессорская дача} {на берегу} {Финского залива}]. [{В отсутствие} хозяина], [друга {моего отца}], [{нашей семье} позволялось там жить]. [Даже {спустя десятилетия} помню], [как после {утомительной дороги} {из города} меня обволакивала прохлада {деревянного дома}], [как собирала растрясшееся], [распавшееся {в экипаже} тело]. [{Эта прохлада} не была связана {со свежестью}], [скорее], [как ни странно], — [с {упоительной затхлостью}], [в которой слились ароматы старых книг и многочисленных {океанских трофеев}], [непонятно как доставшихся профессору-юристу]. [Распространяя {солоноватый запах}], [{на полках} лежали засушенные {морские звёзды}], [{перламутровые раковины}], [{резные маски}], [{пробковый шлем} и даже игла рыбы-иглы].
#
# [Аккуратно отодвигая дары моря], [я доставал {с полок} книги], [садился по-турецки {в кресло} с {самшитовыми подлокотниками} и читал]. [Листал страницы {правой рукой}], [а левая сжимала кусок хлеба {с маслом} и сахаром]. [Откусывал задумчиво и читал], [и сахар скрипел на {моих зубах}]. [Это были жюль-{верновские романы} или журнальные], [переплетённые {в кожу} описания {экзотических стран}] — [мир неведомый], [недоступный и {от юриспруденции} бесконечно далёкий]. [На {своей даче} профессор собрал], [очевидно], [то], [о чём ему мечталось {с детства}], [что не предусматривалось его {нынешним положением} и не регулировалось] «[Сводом законов {Российской империи}]». [В милых его сердцу странах законов], [подозреваю], [не было вообще].
#
# [Время {от времени} я поднимал глаза {от книги} и], [наблюдая угасание залива {за окном}], [пытался понять], [как становятся юристами]. [Мечтают об этом {с детства}]? [Сомнительно]. [{В детстве} я мечтал быть дирижёром или], [скажем], [брандмейстером], [но юристом] — [никогда]. [Ещё я представлял себе], [будто остался в этой {прохладной комнате} навеки], [живу в ней], [как {в капсуле}], [а {за окном} перемены], [перевороты], [землетрясения], [и нет там больше ни сахара], [ни масла], [ни даже {Российской империи}] — [и только я всё сижу и читаю], [читаю]… [{Дальнейшая жизнь} показала], [что {с сахаром} и маслом я угадал], [а вот сидеть и читать] — [этого], [увы], [не получилось].
#
# [Мы в {Полежаевском парке}], [середина июня]. [Там течет речка Лиговка], [она небольшая совсем], [но {в парке} превращается {в озеро}]. [{На воде}] — [лодки], [{на траве}] — [{клетчатые пледы}], [скатерти {с бахромой}], [самовары]. [Я наблюдаю за тем], [как компания], [сидящая неподалеку], [заводит патефон]. [Кто именно сидит], [уже не помню], [но всё еще вижу], [как вращается ручка]. [{Через мгновение} раздается музыка] — [хриплая], [заикающаяся], [и всё же музыка].
#
# [Ящик], [{полный маленьких}], [простуженных], [поющих], [пусть извне и невидимых], — [у меня такого не было]. [И как же я хотел им обладать]: [заботиться о нём], [лелеять], [ставить зимой {у печи}], [но главное] — [заводить его с {царственной небрежностью}], [как делают вещь давно привычную]. [Вращение ручки казалось мне простой и одновременно {неочевидной причиной} льющихся звуков], [{своего рода} {универсальной отмычкой} к прекрасному]. [Было в этом что-то моцартовское], [что-то {от взмаха} {дирижерской палочки}], [оживляющего {немые инструменты} и {земными законами} также не вполне объяснимого]. [Я], [бывало], [дирижировал наедине с собой], [напевая услышанные мелодии], [и неплохо у меня получалось]. [Если бы не мечта стать брандмейстером], [то хотел бы я быть], [конечно же], [дирижером].
#
# [В тот {июньский день} мы видели и дирижера]. [С послушным его руке оркестром он потихоньку удалялся {от берега}]. [Не парковый был оркестр], [не духовой] — [симфонический]. [Стоял {на плоту}], [непонятно как поместившись], [и {по воде} растекалась его музыка], [и ее вполуха слушали отдыхающие]. [Вокруг плота плавали лодки], [утки], [слышны были то скрип уключин], [то кряканье], [но всё это легко врастало {в музыку} и принималось дирижером {в целом} благосклонно]. [Окруженный музыкантами], [дирижер был в то же время одинок]: [есть в {этой профессии} {непостижимый трагизм}]. [Он], [быть может], [выражен не так ярко], [как {у брандмейстера}], [поскольку не связан ни {с огнем}], [ни с {внешними обстоятельствами} вообще], [но эта внутренняя], [скрытая его природа жжет сердца тем сильней].
#
# [Я видел], [как по Невскому ехали тушить пожар] — [{ранней осенью}], [{на исходе} дня]. [Впереди {на вороном} коне] — «[скачок]» ([так называли {передового всадника} {пожарного обоза}]), [{с трубой} {у рта}], [как ангел Апокалипсиса]. [Скачок трубит], [расчищая путь], [и все бросаются врассыпную]. [Извозчики хлещут лошадей], [прижимают их {к обочинам} и замирают], [стоя к пожарным вполоборота]. [И вот по бурлящему Невскому в образовавшейся пустоте мчится колесница], [{несущая огнеборцев}]: [они сидят на {длинной лавке}], [спиной друг {к другу}], [в {медных касках}], [и над ними развевается знамя {пожарной части}]; [{у знамени}] — [брандмейстер], [он звонит {в колокол}]. [В {своём бесстрастии} пожарные трагичны], [на их лицах играют отблески пламени], [которое уже где-то разгорелось], [уже где-то их ждёт], [{до поры} невидимое].
#
# [На едущих печально слетают огненно-{жёлтые листья} из {Екатерининского сада}], [где {свой пожар}]. [Мы {с мамой} стоим у {кованой решётки} и наблюдаем], [как невесомость листьев передаётся обозу]: [он медленно отрывается {от брусчатки} и на {небольшой высоте} летит над Невским]. [{За линейкой} с пожарными проплывает повозка с {паровым насосом}] ([{из котла}] — [пар], [{из трубы}] — [дым]), [за ней] — [{медицинский фургон}], [чтобы спасать обожжённых]. [Я плачу], [и мама говорит], [чтобы я не боялся], [только ведь плачу я не {от страха}] — [{от избытка} чувств], [{от восхищения} мужеством и {великой славой} {этих людей}], [оттого], [что так величественно они плывут мимо замершей толпы под {колокольный звон}].
#
# [Я очень хотел стать брандмейстером и {всякий раз}], [видя пожарных], [обращал к ним {беззвучную просьбу} принять меня в их ряды]. [Она], [понятно], [не была услышана], [но сейчас], [{спустя годы}], [я об этом не жалею]. [Тогда же], [проезжая по Невскому {на империале}], [я неизменно представлял], [что направляюсь {на пожар}]: [держался торжественно и немного грустно], [и не знал], [как там всё ещё сложится {при тушении}], [и ловил {восторженные взгляды}], [и {на приветствия} толпы], [слегка откинув голову набок], [отвечал {одними глазами}].
# [Рассказывают], [что древние греки очень любили виноград и после его сбора устраивали праздник {в честь} бога винограда Диониса]. [Свиту Диониса составляли {козлоногие существа}] – [сатиры]. [Изображая их], [эллины надевали {козлиные шкуры}], [бешено скакали и пели] – [словом], [самозабвенно предавались веселью]. [{Такие представления} назывались трагедиями], [что по-древнегречески означало] «[пение козлов]». [Впоследствии эллины призадумались]: [чему бы еще посвятить {такие игрища}]?
#
# [{Простым людям} всегда было интересно знать], [как живут богатые]. [Драматург Софокл начал писать пьесы {про царей}], [и сразу стало ясно]: [цари и те часто плачут и {личная жизнь} у них небезопасна и отнюдь не проста]. [А для того чтобы придать повествованию занимательности], [Софокл решил привлечь актеров], [которые смогли бы сыграть его произведения], – [так появился театр].
#
# [Вначале поклонники искусства были очень недовольны]: [действие видели только те], [кто сидел {в первом} ряду], [и], [поскольку билеты тогда еще не были предусмотрены], [{лучшие места} занимали самые сильные и рослые]. [Тогда эллины решили устранить это неравноправие и построили амфитеатр], [где каждый {следующий ряд} был выше предыдущего], [и всё], [что происходило {на сцене}], [стало видно всем пришедшим {на представление}].
#
# [{В спектакле} обычно участвовали не только актеры], [но и хор], [вещавший {от имени} народа]. [Например], [выходил герой {на арену} и произносил]:
#
# – [Я сейчас пойду сделаю что-нибудь плохое]!
#
# – [Совершать плохое бессовестно]! – [завывал хор].
#
# – [Ладно], – [поразмыслив], [нехотя соглашался герой]. – [Тогда я пойду и сделаю что-нибудь хорошее].
#
# – [Хорошее делать хорошо], – [одобрял его хор], [тем самым как бы нечаянно подталкивая героя {к гибели}]: [ведь], [как положено {в трагедии}], [за {хорошие дела} неизбежно наступает расплата].
#
# [Правда], [иногда появлялся] «[бог {из машины}]» ([машиной называли {специальный кран}], [на котором] «[бога]» [опускали {на сцену}]) [и нежданно- негаданно спасал героя]. [Был ли это действительно {настоящий бог} или всё-таки актер] – [неясно до {сих пор}], [но зато доподлинно известно], [что и слово] «[машина]», [и {театральные краны} были придуманы в {Древней Греции}].
#
# [В те {незапамятные времена}], [когда {в междуречье} Тигра и Евфрата пришли шумеры], [они говорили на никому не {понятном языке}]: [ведь шумеры были первооткрывателями {новых земель} и язык у них был как у {настоящих разведчиков}] – [тайный], [зашифрованный]. [Ни у кого {такого языка} не было и нет], [разве что у {других разведчиков}].
#
# [А между тем народ {в Месопотамии} уже вовсю пользовался клиньями]: [юноши подбивали клинья {под девушек}] ([так они за ними ухаживали]); [мечи и ножи], [выкованные из дамасской стали], [имели {клиновидную форму}]; [даже журавли {в небе}] – [и те летали клином]. [Шумеры видели вокруг себя так много клиньев], [что и письменность изобрели] – [клиньями]. [Так появилась клинопись] – [самая древняя {в мире} система письма].
#
# [{Во время} уроков в {шумерской школе} ученики {деревянными палочками} выдавливали клинья на {глиняных табличках}], [и оттого всё вокруг было измазано глиной] – [от пола и {до потолка}]. [Уборщицы {в конце} концов рассвирепели], [потому что от {такой учёбы} {в школе} {одна грязь}], [а им ведь надо поддерживать чистоту]. [А для того чтобы поддерживать чистоту], [должно быть чисто], [иначе нечего и поддерживать].
#
# [А вот в {Древнем Египте} письменность состояла {из рисунков}]. [Египтяне подумали]: [зачем писать слово] «[бык]», [если можно этого быка просто нарисовать]? [{Такие слова}-рисунки древние греки] ([или эллины], [как они себя именовали]) [впоследствии назвали иероглифами]. [Уроки письма по-древнеегипетски скорее напоминали уроки рисования], [а выводить иероглифы было настоящим искусством].
#
# – [Ну нет], – [сказали финикийцы]. – [Мы люди работящие], [ремесленники и мореплаватели], [и нам не нужна {изощрённая каллиграфия}], [пусть у нас будет письменность попроще].
#
# [И придумали буквы] – [так получился алфавит]. [Люди стали писать буквами], [и чем дальше], [тем быстрее]. [А чем быстрее они писали], [тем некрасивее у них получалось]. [Больше всех писали врачи]: [они выписывали рецепты]. [Поэтому у некоторых из них до {сих пор} {такой почерк}], [что пишут они вроде бы буквы], [а выходят иероглифы].
# [Древние греки придумали {Олимпийские игры}], [пока вели одну из своих {нескончаемых войн}]. [{Основных причин} было две]: [во-первых], [{во время} баталий солдатам и офицерам некогда было заниматься спортом], [а ведь эллины] ([так называли себя древние греки]) [стремились тренироваться {всё время}], [не {занятое упражнениями} {в философии}]; [во-вторых], [воинам хотелось поскорее вернуться домой], [а отпуск {на войне} не предоставлялся]. [Было ясно], [что войска нуждались {в перемирии} и что {единственной возможностью} его объявить могли стать {Олимпийские игры}]: [ведь {непременное условие} Олимпиады] – [прекращение войны].
#
# [Сначала эллины хотели проводить {Олимпийские игры} ежегодно], [но впоследствии поняли], [что {частые перерывы} {в боевых} действиях бесконечно удлиняют войны], [поэтому {Олимпийские игры} стали объявлять только раз в четыре года]. [{Зимних игр} в {те времена}], [конечно же], [не было], [потому что {в Элладе} не было ни {ледовых арен}], [ни {горнолыжных трасс}].
#
# [В {Олимпийских играх} мог участвовать любой гражданин], [но богатые могли позволить себе дорогостоящее {спортивное снаряжение}], [а бедные] – [нет]. [Чтобы богатые не побеждали бедных только оттого], [что их спортинвентарь лучше], [{все атлеты} мерились силой и ловкостью обнажёнными].
#
# – [А почему игры назывались Олимпийскими]? – [спросите вы]. – [Боги {с Олимпа} тоже принимали в них участие]?
#
# [Нет], [боги], [{кроме ссор} между собой], [никаким {другим спортом} не занимались], [но любили с нескрываемым от {смертных азартом} следить за {спортивными состязаниями} {из поднебесья}]. [А чтобы богам сподручнее было наблюдать {за перипетиями} соревнований], [{первый стадион} построили {в святилище}], [которое называлось Олимпия], – [так игры получили {свое название}].
#
# [Боги и те {на время} игр заключали между собой перемирие и клялись не помогать {своим избранникам}]. [Более того], [они даже разрешали эллинам считать победителей богами] – [правда], [временными], [всего на {один день}]. [Чемпионы-олимпийцы удостаивались оливковых и лавровых венков]: [медалей тогда еще не придумали], [а лавр в {Древней Греции} ценился {на вес} золота], [так что {лавровый венок} тогда был всё равно что {золотая медаль} сегодня].
# [{Мой дед} родился {в Кронштадте}], [{моя жена}] – [ленинградка], [так что {в Петербурге} я чувствую себя не совсем чужим]. [Впрочем], [{в России} трудно найти человека],[в {чьей жизни} {этот город} ничего бы не значил]. [Все мы так или иначе связаны с ним], [а через него друг {с другом}].
#
# [{В Петербурге} мало зелени], [зато много воды и неба]. [Город раскинулся {на равнине}], [и небо над ним необъятно]. [Можно подолгу наслаждаться спектаклями], [которые на {этой сцене} разыгрывают облака и закаты]. [Актерами управляет лучший {на свете} режиссер] – [ветер]. [Декорации {из крыш}], [куполов и шпилей остаются неизменными], [но никогда не надоедают].
#
# [В 1941 году Гитлер решил выморить ленинградцев голодом и стереть город {с лица} земли]. «[Фюрер не понимал], [что распоряжение взорвать Ленинград равносильно приказу взорвать Альпы]», – [заметил писатель Даниил Гранин]. [Петербург] – [{каменная громада}],[по {своей слитности} и мощи не имеющая равных среди {европейских столиц}]. [В нем сохранилось свыше восемнадцати тысяч зданий], [построенных до 1917 года]. [Это больше],[чем {в Лондоне} и Париже], [не говоря уж {о Москве}].
#
# [Через несокрушимый], [высеченный {из камня} лабиринт течет Нева с ее притоками], [протоками и каналами]. [{В отличие} {от неба}], [вода здесь не свободна], [она говорит {о могуществе} империи], [сумевшей заковать ее {в гранит}]. [Летом {у парапетов} {на набережных} стоят рыбаки {с удочками}]. [{Под ногами} у них лежат {полиэтиленовые кульки}], [в которых трепещут пойманные рыбешки]. [Такие же ловцы плотвы и кóрюшки стояли здесь и {при Пушкине}]. [Так же серели тогда бастионы {Петропавловской крепости} и дыбил коня {Медный всадник}]. [Разве что {Зимний дворец} был темно-красным], [а не зеленым], [как сейчас].
#
# [Кажется], [ничто вокруг не напоминает о том], [что в {двадцатом столетии} трещина {русской истории} прошла {через Петербург}]. [Его красота позволяет нам забыть о перенесенных им {немыслимых испытаниях}].
#
# [Когда с {левого берега} Камы], [на котором лежит моя {родная Пермь}], [смотришь {на правый} с его синеющими {до горизонта} лесами], [чувствуешь зыбкость границы {между цивилизацией} и {первозданной лесной} стихией]. [Их разделяет только полоса воды], [и она же их объединяет]. [Если ребенком вы жили {в городе} на {большой реке}], [вам повезло]: [суть жизни вы понимаете лучше], [чем те], [кто был лишен этого счастья].
#
# [В моем детстве {в Каме} еще водилась стерлядь]. [{В старину} ее отправляли {в Петербург} к {царскому столу}], [а чтобы не испортилась {в пути}], [{под жабры} клали смоченную {в коньяке} вату]. [Мальчиком я видел {на песке} {маленького осетра} с испятнанной мазутом зубчáтой спиной]: [{вся Кама} была тогда {в мазуте} {от буксиров}]. [Эти {грязные трудяги} тащили за собой плоты и баржи]. [{На палубах} бегали дети и сушилось {на солнце} белье]. [{Нескончаемые вереницы} сбитых скобами {осклизлых бревен} исчезли вместе {с буксирами} и баржами]. [Кама стала чище], [но стерлядь {в нее} так и не вернулась].
#
# [Говорили], [что Пермь], [подобно Москве и Риму], [лежит на семи холмах]. [Этого было достаточно], [чтобы ощутить], [как над моим деревянным], [утыканным {заводскими трубами} городом веет дыхание истории]. [Его улицы идут или параллельно Каме], [или перпендикулярно ей]. [Первые {до революции} назывались по стоявшим на них храмам], [как], [например], [Вознесенская или Покровская]. [Вторые носили имена {тех мест}], [куда вели вытекающие из них дороги]: [Сибирская], [Соликамская], [Верхотурская]. [Там], [где они пересекались], [небесное встречалось с земным]. [Здесь я понял], [что дольнее рано или поздно сходится с горним], [нужно лишь набраться терпения и подождать].
#
# [Пермяки утверждают], [что не Кама впадает {в Волгу}], [а], [наоборот], [Волга {в Каму}]. [Мне не важно], [какая из двух {этих великих} рек является притоком другой]. [В любом случае Кама] – [{та река}], [которая течет через {мое сердце}].
#
# [Названия рек древнее всех {других имен}], [нанесенных {на карты}]. [Нам не всегда понятен их смысл], [вот и Селенга хранит тайну {своего имени}]. [Оно произошло не то от {бурятского слова}] «[сэл]», [что значит] «[разлив]», [не то от эвенкийского] «[сэлэ]», [то есть] «[железо]», [но мне слышалось в нем имя {греческой богини} луны], [Селены]. [Стиснутая поросшими лесом сопками], [часто окутанная туманом Селенга была для меня загадочной] «[{лунной рекой}]». [{В шуме} ее течения мне], [{юному лейтенанту}], [чудилось обещание любви и счастья]. [Казалось], [они ожидают меня впереди так же непреложно], [как Селенгу ждет Байкал].
#
# [Может быть], [то же обещала она {двадцатилетнему поручику} Анатолию Пепеляеву], [будущему {белому генералу} и поэту]. [Незадолго до Первой {мировой войны} он тайно обвенчался со {своей избранницей} в бедной {сельской церкви} {на берегу} Селенги]. [Отец-дворянин не дал сыну благословения на {неравный брак}]. [Невеста была внучкой ссыльных и дочерью {простого железнодорожника} {из Верхнеудинска}] –[так прежде назывался Улан-Удэ].
#
# [Я застал {этот город} почти таким], [каким его видел Пепеляев]. [{На рынке} торговали бараниной приехавшие {из глубинки} буряты в традиционных {синих халатах} и прохаживались женщины в {музейных сарафанах}]. [Они продавали нанизанные {на руки}], [как калачи], [круги мороженого молока]. [Это были] «[семейские]», [как {в Забайкалье} именуют старообрядцев], [раньше живших {большими семьями}]. [Правда], [появилось и то], [чего {при Пепеляеве} не было]. [Помню], [как на {главной площади} поставили самый оригинальный из всех виденных мною памятников Ленину]: [на {невысоком пьедестале} круглилась громадная], [{без шеи} и туловища], [{гранитная голова} вождя], [похожая {на голову} богатыря-исполина из] «[Руслана и Людмилы]». [Она до {сих пор} стоит {в столице} Бурятии и стала одним из ее символов]. [Здесь история и современность], [православие и буддизм не отторгают и не подавляют друг друга]. [Улан-Удэ подарил мне надежду], [что и в {других местах} это возможно].
# [{Каждое утро}], [еще {при свете} звезд], [Якоб Иванович Бах просыпался и], [лежа {под толстой} {стеганой периной} {утиного пуха}], [слушал мир]. [Тихие {нестройные звуки} текущей где-то вокруг него и поверх него {чужой жизни} успокаивали]. [Гуляли {по крышам} ветры] – [зимой тяжелые], [густо замеша]/[енные {со снегом} и {ледяной крупой}], [весной упругие], [дышащие влагой и {небесным электричеством}], [летом вялые], [сухие], [вперемешку {с пылью} и легким {ковыльным семенем}]. [Лаяли собаки], [приветствуя вышедших {на крыльцо} {сонных хозяев}], [и басовито ревел скот {на пути} {к водопою}]. [Мир дышал], [трещал], [свистел], [мычал], [стучал копытами], [звенел и пел на {разные голоса}].
#
# [Звуки же {собственной жизни} были столь скудны и вопиюще незначительны], [что Бах разучился их слышать]: [вычленял в общем {звуковом потоке} и пропускал мимо ушей]. [Дребезжало {под порывами} ветра стекло единственного {в комнате} окна], [потрескивал давно не чищенный дымоход], [изредка посвистывала откуда-то {из-под печи} {седая мышь}]. [Вот], [пожалуй], [и все]. [Слушать {большую жизнь} было не {в пример} интереснее]. [Иногда], [заслушавшись], [Бах даже забывал], [что он и {сам часть} этого мира], [что и он мог бы], [выйдя {на крыльцо}], [присоединиться {к многоголосью}]: [спеть что-нибудь задорное], [или громко хлопнуть дверью], [или], [на {худой конец}], [просто чихнуть]. [Но Бах предпочитал слушать].
# [В шесть утра], [тщательно одетый и причесанный], [он уже стоял у {пришкольной колокольни} с карманными часами {в руках}]. [Дождавшись], [когда обе стрелки сольются в {единую линию}] ([часовая на шести], [минутная на двенадцати]), [что есть силы дергал {за веревку}] – [и {бронзовый колокол} гулко отзывался]. [За многие годы упражнений Бах достиг в этом деле {такого мастерства}], [что звук удара раздавался ровно в {тот момент}], [когда {минутная стрелка} касалась {циферблатного зенита}], [и ни секундой позже]. [Мгновение спустя каждый {в деревне} поворачивался {на звук} и шептал {короткую молитву}]. [Наступал {новый день}].
#
# [{За годы} учительства], [каждый из которых напоминал предыдущий и ничем особенным не выделялся], [Якоб Иванович настолько привык произносить одни и те же слова и зачитывать одни и те же задачки], [что научился при этом мысленно раздваиваться внутри {своего тела}]: [язык его бормотал текст очередного {грамматического правила}], [рука зажатой в ней линейкой вяло шлепала {по затылку} чересчур {говорливого ученика}], [ноги степенно несли тело {по классу}] ‒ [{от кафедры} к {задней стене}], [затем обратно], [туда-сюда]. [А мысль дремала], [убаюканная его же {собственным голосом} и {мерным покачиванием} головы {в такт} {неспешным шагам}].
#
# [{Немецкая речь} была {единственным предметом}], [{во время} {которого мысль} Баха обретала {былую свежесть} и бодрость]. [Начинали урок с {устных упражнений}]. [Ученикам предлагалось рассказать что-либо], [Бах слушал и переводил]: [перелицовывал короткие {диалектные обороты} в {элегантные фразы} литературного немецкого]. [Двигались не спеша], [предложение {за предложением}], [слово {за словом}], [будто шли куда-то по {глубокому снегу}] – [след {в след}]. [Копаться {с азбукой} и чистописанием Якоб Иванович не любил и], [разделавшись {с разговорами}], [торопливо стремил урок к {поэтической части}]: [стихи лились на юные {лохматые головы} щедро], [как вода {из лоханки} в {банный день}].
#
# [Любовью {к поэзии} Баха обожгло еще {в юности}]. [Тогда казалось]: [он питается не {картофельным супом} и {квашеной капустой}], [а одними лишь балладами и гимнами]. [Казалось], [ими же сможет накормить и всех вокруг] – [потому и стал учителем]. [До {сих пор}], [декламируя {на уроке} {любимые строфы}], [Бах все еще чувствовал {прохладное трепетание} восторга {в груди}]. [Дети страсти педагога не разделяли]: [лица их], [обычно шаловливые или сосредоточенные], [с первыми же звуками {стихотворных строк} приобретали покорное {сомнамбулическое выражение}]. [{Немецкий романтизм} действовал {на класс} лучше снотворного]. [Пожалуй], [чтение стихов можно было использовать {для успокоения} расшалившейся аудитории вместо {привычных криков} и ударов линейкой].
#
# [Бах спускался {с крыльца} школы и оказывался {на площади}], [{у подножия} {величественной кирхи} с {просторным молельным} залом {в кружеве} {стрельчатых окон} и громадной колокольней], [напоминающей остро заточенный карандаш]. [Шёл мимо аккуратных {деревянных домиков} с небесно-синими], [ягодно-красными и кукурузно-{жёлтыми наличниками}]; [мимо струганых заборов]; [мимо перевёрнутых {в ожидании} паводка лодок]; [мимо палисадников с {рябиновыми кустами}]. [Шёл так стремительно], [громко хрустя валенками {по снегу} или хлюпая башмаками по {весенней грязи}], [что можно было подумать], [будто у него десяток {безотлагательных дел}], [которые непременно следует уладить сегодня]…
#
# [Встречные], [замечая семенящую фигурку учителя], [иногда окликали его и заговаривали о {школьных успехах} {своих отпрысков}]. [Однако тот], [запыхавшийся от {быстрой ходьбы}], [отвечал неохотно], [{короткими фразами}]: [времени было {в обрез}]. [{В подтверждение} доставал {из кармана} часы], [бросал на них сокрушённый взгляд и], [качая головой], [бежал дальше]. [Куда он бежал], [Бах и сам не смог бы объяснить].
#
# [Надо сказать], [была ещё {одна причина} его торопливости]: [беседуя {с людьми}], [Якоб Иванович заикался]. [Его тренированный язык], [мерно и безотказно работавший {во время} уроков и без {единой запинки} произносивший {многосоставные слова} литературного немецкого], [легко выдавал такие {сложноподчинённые коленца}], [что {иной ученик} и начало забудет], [пока {до конца} дослушает]. [Тот же {самый язык} вдруг начинал отказывать хозяину], [когда Бах переходил {на диалект} {в разговорах} {с односельчанами}]. [Читать наизусть отрывки из] «[Фауста]», [{к примеру}], [язык желал]; [сказать же соседке]: «[А балбес-то ваш нынче опять шалопайничал]!» ‒ [не желал никак], [прилипал {к нёбу} и мешался {меж зубов}], [как чересчур большая и плохо проваренная клёцка]. [Баху казалось], [что с годами заикание усиливается], [но проверить это было затруднительно]: [беседовал {с людьми} он {всё реже} и реже]… [Так текла жизнь], [в которой было всё], [кроме {самой жизни}], ‒ [спокойная], [полная {грошовых радостей} и {мизерных тревог}], [некоторым образом даже счастливая].

# %%
for word in (mystem.lemmatize(texts[0])):
    print(word, end=' is ')
    print(getPos(word))
# Out:
# профессорский is ADJF
#   is None
# дача is NOUN
#   is None
# на is PREP
#   is None
# берег is NOUN
#   is None
# финский is ADJF
#   is None
# залив is NOUN
# .  is None
# в is PREP
#   is None
# отсутствие is NOUN
#   is None
# хозяин is NOUN
# ,  is None
# друг is NOUN
#   is None
# мой is ADJF
#   is None
# отец is NOUN
# ,  is None
# наш is ADJF
#   is None
# семья is NOUN
#   is None
# позволяться is INFN
#   is None
# там is ADVB
#   is None
# жить is INFN
# .  is None
# даже is PRCL
#   is None
# спустя is PREP
#   is None
# десятилетие is NOUN
#   is None
# помнить is INFN
# ,  is None
# как is CONJ
#   is None
# после is PREP
#   is None
# утомительный is ADJF
#   is None
# дорога is NOUN
#   is None
# из is PREP
#   is None
# город is NOUN
#   is None
# я is NPRO
#   is None
# обволакивать is INFN
#   is None
# прохлада is NOUN
#   is None
# деревянный is ADJF
#   is None
# дома is NOUN
# ,  is None
# как is CONJ
#   is None
# собирать is INFN
#   is None
# растрясаться is INFN
# ,  is None
# распадаться is INFN
#   is None
# в is PREP
#   is None
# экипаж is NOUN
#   is None
# тело is NOUN
# .  is None
# этот is ADJF
#   is None
# прохлада is NOUN
#   is None
# не is PRCL
#   is None
# быть is INFN
#   is None
# связанный is ADJF
#   is None
# со is PREP
#   is None
# свежесть is NOUN
# ,  is None
# скоро is ADVB
# ,  is None
# как is CONJ
#   is None
# ни is PRCL
#   is None
# странный is ADJF
# , —  is None
# с is PREP
#   is None
# упоительный is ADJF
#   is None
# затхлость is NOUN
# ,  is None
# в is PREP
#   is None
# который is ADJF
#   is None
# сливаться is INFN
#   is None
# аромат is NOUN
#   is None
# старый is ADJF
#   is None
# книга is NOUN
#   is None
# и is CONJ
#   is None
# многочисленный is ADJF
#   is None
# океанский is ADJF
#   is None
# трофей is NOUN
# ,  is None
# непонятно is ADVB
#   is None
# как is CONJ
#   is None
# доставаться is INFN
#   is None
# профессор is NOUN
# - is None
# юрист is NOUN
# .  is None
# распространять is INFN
#   is None
# солоноватый is ADJF
#   is None
# запах is NOUN
# ,  is None
# на is PREP
#   is None
# полка is NOUN
#   is None
# лежать is INFN
#   is None
# засушивать is INFN
#   is None
# морской is ADJF
#   is None
# звезда is NOUN
# ,  is None
# перламутровый is ADJF
#   is None
# раковина is NOUN
# ,  is None
# резной is ADJF
#   is None
# маска is NOUN
# ,  is None
# пробковый is ADJF
#   is None
# шлем is NOUN
#   is None
# и is CONJ
#   is None
# даже is PRCL
#   is None
# игла is NOUN
#   is None
# рыба is NOUN
# - is None
# игла is NOUN
# . is None
#
#  is None
#
#  is None
# аккуратно is ADVB
#   is None
# отодвигать is INFN
#   is None
# дар is NOUN
#   is None
# море is NOUN
# ,  is None
# я is NPRO
#   is None
# доставать is INFN
#   is None
# с is PREP
#   is None
# полка is NOUN
#   is None
# книга is NOUN
# ,  is None
# садиться is INFN
#   is None
# по-турецки is NOUN
#   is None
# в is PREP
#   is None
# кресло is NOUN
#   is None
# с is PREP
#   is None
# самшитовый is ADJF
#   is None
# подлокотник is NOUN
#   is None
# и is CONJ
#   is None
# читать is INFN
# .  is None
# листать is INFN
#   is None
# страница is NOUN
#   is None
# правый is NOUN
#   is None
# рука is NOUN
# ,  is None
# а is CONJ
#   is None
# левый is ADJF
#   is None
# сжимать is INFN
#   is None
# кусок is NOUN
#   is None
# хлеб is NOUN
#   is None
# с is PREP
#   is None
# масло is NOUN
#   is None
# и is CONJ
#   is None
# сахар is NOUN
# .  is None
# откусывать is INFN
#   is None
# задумчиво is ADVB
#   is None
# и is CONJ
#   is None
# читать is INFN
# ,  is None
# и is CONJ
#   is None
# сахар is NOUN
#   is None
# скрипеть is INFN
#   is None
# на is PREP
#   is None
# мой is ADJF
#   is None
# зуб is NOUN
# .  is None
# это is PRCL
#   is None
# быть is INFN
#   is None
# жюль is NOUN
# - is None
# верновский is ADJF
#   is None
# роман is NOUN
#   is None
# или is CONJ
#   is None
# журнальный is ADJF
# ,  is None
# переплетать is INFN
#   is None
# в is PREP
#   is None
# кожа is NOUN
#   is None
# описание is NOUN
#   is None
# экзотический is ADJF
#   is None
# страна is NOUN
#  —  is None
# мир is NOUN
#   is None
# неведомый is ADJF
# ,  is None
# недоступный is ADJF
#   is None
# и is CONJ
#   is None
# от is PREP
#   is None
# юриспруденция is NOUN
#   is None
# бесконечно is ADVB
#   is None
# далекий is ADJF
# .  is None
# на is PREP
#   is None
# свой is ADJF
#   is None
# дача is NOUN
#   is None
# профессор is NOUN
#   is None
# собирать is INFN
# ,  is None
# очевидно is CONJ
# ,  is None
# то is CONJ
# ,  is None
# о is PREP
#   is None
# что is CONJ
#   is None
# он is NPRO
#   is None
# мечтаться is INFN
#   is None
# с is PREP
#   is None
# детство is NOUN
# ,  is None
# что is CONJ
#   is None
# не is PRCL
#   is None
# предусматриваться is INFN
#   is None
# его is NPRO
#   is None
# нынешний is ADJF
#   is None
# положение is NOUN
#   is None
# и is CONJ
#   is None
# не is PRCL
#   is None
# регулироваться is INFN
#  « is None
# свод is NOUN
#   is None
# закон is NOUN
#   is None
# российский is ADJF
#   is None
# империя is NOUN
# » is None
# .  is None
# в is PREP
#   is None
# милый is ADJF
#   is None
# его is NPRO
#   is None
# сердце is NOUN
#   is None
# страна is NOUN
#   is None
# закон is NOUN
# ,  is None
# подозревать is INFN
# ,  is None
# не is PRCL
#   is None
# быть is INFN
#   is None
# вообще is ADVB
# . is None
#
#  is None
#
#  is None
# время is NOUN
#   is None
# от is PREP
#   is None
# время is NOUN
#   is None
# я is NPRO
#   is None
# подымать is INFN
#   is None
# глаз is NOUN
#   is None
# от is PREP
#   is None
# книга is NOUN
#   is None
# и is CONJ
# ,  is None
# наблюдать is INFN
#   is None
# угасание is NOUN
#   is None
# залив is NOUN
#   is None
# за is PREP
#   is None
# окно is NOUN
# ,  is None
# пытаться is INFN
#   is None
# понимать is INFN
# ,  is None
# как is CONJ
#   is None
# становиться is INFN
#   is None
# юрист is NOUN
# .  is None
# мечтать is INFN
#   is None
# об is PREP
#   is None
# это is PRCL
#   is None
# с is PREP
#   is None
# детство is NOUN
# ?  is None
# сомнительно is ADVB
# .  is None
# в is PREP
#   is None
# детство is NOUN
#   is None
# я is NPRO
#   is None
# мечтать is INFN
#   is None
# быть is INFN
#   is None
# дирижер is NOUN
#   is None
# или is CONJ
# ,  is None
# скажем is CONJ
# ,  is None
# брандмейстер is NOUN
# ,  is None
# но is CONJ
#   is None
# юрист is NOUN
#  —  is None
# никогда is ADVB
# .  is None
# еще is PRCL
#   is None
# я is NPRO
#   is None
# представлять is INFN
#   is None
# себя is NPRO
# ,  is None
# будто is CONJ
#   is None
# оставаться is INFN
#   is None
# в is PREP
#   is None
# этот is ADJF
#   is None
# прохладный is ADJF
#   is None
# комната is NOUN
#   is None
# навеки is ADVB
# ,  is None
# жить is INFN
#   is None
# в is PREP
#   is None
# она is NPRO
# ,  is None
# как is CONJ
#   is None
# в is PREP
#   is None
# капсула is NOUN
# ,  is None
# а is CONJ
#   is None
# за is PREP
#   is None
# окно is NOUN
#   is None
# перемена is NOUN
# ,  is None
# переворот is NOUN
# ,  is None
# землетрясение is NOUN
# ,  is None
# и is CONJ
#   is None
# нет is PRED
#   is None
# там is ADVB
#   is None
# больше is COMP
#   is None
# ни is PRCL
#   is None
# сахар is NOUN
# ,  is None
# ни is PRCL
#   is None
# масло is NOUN
# ,  is None
# ни is PRCL
#   is None
# даже is PRCL
#   is None
# российский is ADJF
#   is None
# империя is NOUN
#  —  is None
# и is CONJ
#   is None
# только is PRCL
#   is None
# я is NPRO
#   is None
# все is ADJF
#   is None
# сидеть is INFN
#   is None
# и is CONJ
#   is None
# читать is INFN
# ,  is None
# читать is INFN
# …  is None
# дальнейший is ADJF
#   is None
# жизнь is NOUN
#   is None
# показывать is INFN
# ,  is None
# что is CONJ
#   is None
# с is PREP
#   is None
# сахар is NOUN
#   is None
# и is CONJ
#   is None
# масло is NOUN
#   is None
# я is NPRO
#   is None
# угадывать is INFN
# ,  is None
# а is CONJ
#   is None
# вот is PRCL
#   is None
# сидеть is INFN
#   is None
# и is CONJ
#   is None
# читать is INFN
#  —  is None
# это is PRCL
# ,  is None
# увы is INTJ
# ,  is None
# не is PRCL
#   is None
# получаться is INFN
# . is None
#
#  is None
#
#  is None
# мы is NPRO
#   is None
# в is PREP
#   is None
# полежаевский is ADJF
#   is None
# парк is NOUN
# ,  is None
# середина is NOUN
#   is None
# июнь is NOUN
# .  is None
# там is ADVB
#   is None
# течь is NOUN
#   is None
# речка is NOUN
#   is None
# лиговка is NOUN
# ,  is None
# она is NPRO
#   is None
# небольшой is ADJF
#   is None
# совсем is ADVB
# ,  is None
# но is CONJ
#   is None
# в is PREP
#   is None
# парк is NOUN
#   is None
# превращаться is INFN
#   is None
# в is PREP
#   is None
# озеро is NOUN
# .  is None
# на is PREP
#   is None
# вода is NOUN
#  —  is None
# лодка is NOUN
# ,  is None
# на is PREP
#   is None
# трава is NOUN
#  —  is None
# клетчатый is ADJF
#   is None
# плед is NOUN
# ,  is None
# скатерть is NOUN
#   is None
# с is PREP
#   is None
# бахрома is NOUN
# ,  is None
# самовар is NOUN
# .  is None
# я is NPRO
#   is None
# наблюдать is INFN
#   is None
# за is PREP
#   is None
# то is CONJ
# ,  is None
# как is CONJ
#   is None
# компания is NOUN
# ,  is None
# сидеть is INFN
#   is None
# неподалеку is ADVB
# ,  is None
# заводить is INFN
#   is None
# патефон is NOUN
# .  is None
# кто is NPRO
#   is None
# именно is PRCL
#   is None
# сидеть is INFN
# ,  is None
# уже is ADVB
#   is None
# не is PRCL
#   is None
# помнить is INFN
# ,  is None
# но is CONJ
#   is None
# все is ADJF
#   is None
# еще is PRCL
#   is None
# видеть is INFN
# ,  is None
# как is CONJ
#   is None
# вращаться is INFN
#   is None
# ручка is NOUN
# .  is None
# через is PREP
#   is None
# мгновение is NOUN
#   is None
# раздаваться is INFN
#   is None
# музыка is NOUN
#  —  is None
# хриплый is ADJF
# ,  is None
# заикаться is INFN
# ,  is None
# и is CONJ
#   is None
# все is ADJF
#   is None
# же is PRCL
#   is None
# музыка is NOUN
# . is None
#
#  is None
#
#  is None
# ящик is NOUN
# ,  is None
# полный is ADJF
#   is None
# маленький is ADJF
# ,  is None
# простужать is INFN
# ,  is None
# петь is INFN
# ,  is None
# пусть is CONJ
#   is None
# извне is ADVB
#   is None
# и is CONJ
#   is None
# невидимый is ADJF
# , —  is None
# у is PREP
#   is None
# я is NPRO
#   is None
# такой is ADJF
#   is None
# не is PRCL
#   is None
# быть is INFN
# .  is None
# и is CONJ
#   is None
# как is CONJ
#   is None
# же is PRCL
#   is None
# я is NPRO
#   is None
# хотеть is INFN
#   is None
# они is NPRO
#   is None
# обладать is INFN
# :  is None
# заботиться is INFN
#   is None
# о is PREP
#   is None
# он is NPRO
# ,  is None
# лелеять is INFN
# ,  is None
# ставить is INFN
#   is None
# зима is NOUN
#   is None
# у is PREP
#   is None
# печь is INFN
# ,  is None
# но is CONJ
#   is None
# главное is ADJF
#  —  is None
# заводить is INFN
#   is None
# он is NPRO
#   is None
# с is PREP
#   is None
# царственный is ADJF
#   is None
# небрежность is NOUN
# ,  is None
# как is CONJ
#   is None
# делать is INFN
#   is None
# вещь is NOUN
#   is None
# давно is ADVB
#   is None
# привычный is ADJF
# .  is None
# вращение is NOUN
#   is None
# ручка is NOUN
#   is None
# казаться is INFN
#   is None
# я is NPRO
#   is None
# простой is NOUN
#   is None
# и is CONJ
#   is None
# одновременно is ADVB
#   is None
# неочевидный is ADJF
#   is None
# причина is NOUN
#   is None
# литься is INFN
#   is None
# звук is NOUN
# ,  is None
# свой is ADJF
#   is None
# род is NOUN
#   is None
# универсальный is ADJF
#   is None
# отмычка is NOUN
#   is None
# к is PREP
#   is None
# прекрасный is ADJF
# .  is None
# быть is INFN
#   is None
# в is PREP
#   is None
# это is PRCL
#   is None
# что-то is NPRO
#   is None
# моцартовский is ADJF
# ,  is None
# что-то is NPRO
#   is None
# от is PREP
#   is None
# взмах is NOUN
#   is None
# дирижерский is ADJF
#   is None
# палочка is NOUN
# ,  is None
# оживлять is INFN
#   is None
# немой is ADJF
#   is None
# инструмент is NOUN
#   is None
# и is CONJ
#   is None
# земной is ADJF
#   is None
# закон is NOUN
#   is None
# также is CONJ
#   is None
# не is PRCL
#   is None
# вполне is ADVB
#   is None
# объяснимый is ADJF
# .  is None
# я is NPRO
# ,  is None
# бывало is VERB
# ,  is None
# дирижировать is INFN
#   is None
# наедине is ADVB
#   is None
# с is PREP
#   is None
# себя is NPRO
# ,  is None
# напевать is INFN
#   is None
# услышать is INFN
#   is None
# мелодия is NOUN
# ,  is None
# и is CONJ
#   is None
# неплохо is ADVB
#   is None
# у is PREP
#   is None
# я is NPRO
#   is None
# получаться is INFN
# .  is None
# если is CONJ
#   is None
# бы is PRCL
#   is None
# не is PRCL
#   is None
# мечта is NOUN
#   is None
# становиться is INFN
#   is None
# брандмейстер is NOUN
# ,  is None
# то is CONJ
#   is None
# хотеть is INFN
#   is None
# бы is PRCL
#   is None
# я is NPRO
#   is None
# быть is INFN
# ,  is None
# конечно is CONJ
#   is None
# же is PRCL
# ,  is None
# дирижер is NOUN
# . is None
#
#  is None
#
#  is None
# в is PREP
#   is None
# тот is ADJF
#   is None
# июньский is ADJF
#   is None
# день is NOUN
#   is None
# мы is NPRO
#   is None
# видеть is INFN
#   is None
# и is CONJ
#   is None
# дирижер is NOUN
# .  is None
# с is PREP
#   is None
# послушный is ADJF
#   is None
# его is NPRO
#   is None
# рука is NOUN
#   is None
# оркестр is NOUN
#   is None
# он is NPRO
#   is None
# потихоньку is ADVB
#   is None
# удаляться is INFN
#   is None
# от is PREP
#   is None
# берег is NOUN
# .  is None
# не is PRCL
#   is None
# парковый is ADJF
#   is None
# быть is INFN
#   is None
# оркестр is NOUN
# ,  is None
# не is PRCL
#   is None
# духовой is NOUN
#  —  is None
# симфонический is ADJF
# .  is None
# стоять is INFN
#   is None
# на is PREP
#   is None
# плот is NOUN
# ,  is None
# непонятно is ADVB
#   is None
# как is CONJ
#   is None
# помещаться is INFN
# ,  is None
# и is CONJ
#   is None
# по is PREP
#   is None
# вода is NOUN
#   is None
# растекаться is INFN
#   is None
# его is NPRO
#   is None
# музыка is NOUN
# ,  is None
# и is CONJ
#   is None
# ее is NPRO
#   is None
# вполуха is ADVB
#   is None
# слушать is INFN
#   is None
# отдыхать is INFN
# .  is None
# вокруг is ADVB
#   is None
# плот is NOUN
#   is None
# плавать is INFN
#   is None
# лодка is NOUN
# ,  is None
# утка is NOUN
# ,  is None
# слышный is ADJF
#   is None
# быть is INFN
#   is None
# то is CONJ
#   is None
# скрип is INTJ
#   is None
# уключина is NOUN
# ,  is None
# то is CONJ
#   is None
# кряканье is NOUN
# ,  is None
# но is CONJ
#   is None
# весь is ADJF
#   is None
# это is PRCL
#   is None
# легко is ADVB
#   is None
# врастать is INFN
#   is None
# в is PREP
#   is None
# музыка is NOUN
#   is None
# и is CONJ
#   is None
# приниматься is INFN
#   is None
# дирижер is NOUN
#   is None
# в is PREP
#   is None
# целое is NOUN
#   is None
# благосклонно is ADVB
# .  is None
# окружать is INFN
#   is None
# музыкант is NOUN
# ,  is None
# дирижер is NOUN
#   is None
# быть is INFN
#   is None
# в is PREP
#   is None
# тот is ADJF
#   is None
# же is PRCL
#   is None
# время is NOUN
#   is None
# одинокий is ADJF
# :  is None
# быть is INFN
#   is None
# в is PREP
#   is None
# этот is ADJF
#   is None
# профессия is NOUN
#   is None
# непостижимый is ADJF
#   is None
# трагизм is NOUN
# .  is None
# он is NPRO
# ,  is None
# быть is INFN
#   is None
# мочь is NOUN
# ,  is None
# выражать is INFN
#   is None
# не is PRCL
#   is None
# так is CONJ
#   is None
# ярко is ADVB
# ,  is None
# как is CONJ
#   is None
# у is PREP
#   is None
# брандмейстер is NOUN
# ,  is None
# поскольку is CONJ
#   is None
# не is PRCL
#   is None
# связанный is ADJF
#   is None
# ни is PRCL
#   is None
# с is PREP
#   is None
# огонь is NOUN
# ,  is None
# ни is PRCL
#   is None
# с is PREP
#   is None
# внешний is ADJF
#   is None
# обстоятельство is NOUN
#   is None
# вообще is ADVB
# ,  is None
# но is CONJ
#   is None
# этот is ADJF
#   is None
# внутренний is ADJF
# ,  is None
# скрытый is ADJF
#   is None
# его is NPRO
#   is None
# природа is NOUN
#   is None
# жечь is INFN
#   is None
# сердце is NOUN
#   is None
# тем is CONJ
#   is None
# сильно is ADVB
# . is None
#
#  is None
#
#  is None
# я is NPRO
#   is None
# видеть is INFN
# ,  is None
# как is CONJ
#   is None
# по is PREP
#   is None
# невский is NOUN
#   is None
# ехать is INFN
#   is None
# тушить is INFN
#   is None
# пожар is NOUN
#  —  is None
# ранний is ADJF
#   is None
# осень is NOUN
# ,  is None
# на is PREP
#   is None
# исход is NOUN
#   is None
# день is NOUN
# .  is None
# впереди is ADVB
#   is None
# на is PREP
#   is None
# ворон is NOUN
#   is None
# конь is NOUN
#  — « is None
# скачок is NOUN
# » ( is None
# так is CONJ
#   is None
# называть is INFN
#   is None
# передовой is ADJF
#   is None
# всадник is NOUN
#   is None
# пожарный is ADJF
#   is None
# обоз is NOUN
# ),  is None
# с is PREP
#   is None
# труба is NOUN
#   is None
# у is PREP
#   is None
# рот is NOUN
# ,  is None
# как is CONJ
#   is None
# ангел is NOUN
#   is None
# апокалипсис is NOUN
# .  is None
# скачок is NOUN
#   is None
# трубить is INFN
# ,  is None
# расчищать is INFN
#   is None
# путь is NOUN
# ,  is None
# и is CONJ
#   is None
# все is ADJF
#   is None
# бросаться is INFN
#   is None
# врассыпную is ADVB
# .  is None
# извозчик is NOUN
#   is None
# хлестать is INFN
#   is None
# лошадь is NOUN
# ,  is None
# прижимать is INFN
#   is None
# они is NPRO
#   is None
# к is PREP
#   is None
# обочина is NOUN
#   is None
# и is CONJ
#   is None
# замирать is INFN
# ,  is None
# стоять is INFN
#   is None
# к is PREP
#   is None
# пожарный is ADJF
#   is None
# вполоборота is ADVB
# .  is None
# и is CONJ
#   is None
# вот is PRCL
#   is None
# по is PREP
#   is None
# бурлить is INFN
#   is None
# невский is NOUN
#   is None
# в is PREP
#   is None
# образовываться is INFN
#   is None
# пустота is NOUN
#   is None
# мчаться is INFN
#   is None
# колесница is NOUN
# ,  is None
# несущий is ADJF
#   is None
# огнеборец is NOUN
# :  is None
# они is NPRO
#   is None
# сидеть is INFN
#   is None
# на is PREP
#   is None
# длинный is ADJF
#   is None
# лавка is NOUN
# ,  is None
# спина is NOUN
#   is None
# друг is NOUN
#   is None
# к is PREP
#   is None
# друг is NOUN
# ,  is None
# в is PREP
#   is None
# медный is ADJF
#   is None
# каска is NOUN
# ,  is None
# и is CONJ
#   is None
# над is PREP
#   is None
# они is NPRO
#   is None
# развеваться is INFN
#   is None
# знамя is NOUN
#   is None
# пожарный is ADJF
#   is None
# часть is NOUN
# ;  is None
# у is PREP
#   is None
# знамя is NOUN
#  —  is None
# брандмейстер is NOUN
# ,  is None
# он is NPRO
#   is None
# звонить is INFN
#   is None
# в is PREP
#   is None
# колокол is NOUN
# .  is None
# в is PREP
#   is None
# свой is ADJF
#   is None
# бесстрастие is NOUN
#   is None
# пожарный is ADJF
#   is None
# трагичный is ADJF
# ,  is None
# на is PREP
#   is None
# их is NPRO
#   is None
# лицо is NOUN
#   is None
# играть is INFN
#   is None
# отблеск is NOUN
#   is None
# пламень is NOUN
# ,  is None
# который is ADJF
#   is None
# уже is ADVB
#   is None
# где-то is ADVB
#   is None
# разгораться is INFN
# ,  is None
# уже is ADVB
#   is None
# где-то is ADVB
#   is None
# они is NPRO
#   is None
# ждать is INFN
# ,  is None
# до is PREP
#   is None
# пора is NOUN
#   is None
# невидимый is ADJF
# . is None
#
#  is None
#
#  is None
# на is PREP
#   is None
# ехать is INFN
#   is None
# печально is ADVB
#   is None
# слетать is INFN
#   is None
# огненный is ADJF
# - is None
# желтый is ADJF
#   is None
# лист is NOUN
#   is None
# из is PREP
#   is None
# екатерининский is ADJF
#   is None
# сад is NOUN
# ,  is None
# где is ADVB
#   is None
# свой is ADJF
#   is None
# пожар is NOUN
# .  is None
# мы is NPRO
#   is None
# с is PREP
#   is None
# мама is NOUN
#   is None
# стоять is INFN
#   is None
# у is PREP
#   is None
# кованый is ADJF
#   is None
# решетка is NOUN
#   is None
# и is CONJ
#   is None
# наблюдать is INFN
# ,  is None
# как is CONJ
#   is None
# невесомость is NOUN
#   is None
# лист is NOUN
#   is None
# передаваться is INFN
#   is None
# обоз is NOUN
# :  is None
# он is NPRO
#   is None
# медленно is ADVB
#   is None
# отрываться is INFN
#   is None
# от is PREP
#   is None
# брусчатка is NOUN
#   is None
# и is CONJ
#   is None
# на is PREP
#   is None
# небольшой is ADJF
#   is None
# высота is NOUN
#   is None
# лететь is INFN
#   is None
# над is PREP
#   is None
# невский is NOUN
# .  is None
# за is PREP
#   is None
# линейка is NOUN
#   is None
# с is PREP
#   is None
# пожарный is ADJF
#   is None
# проплывать is INFN
#   is None
# повозка is NOUN
#   is None
# с is PREP
#   is None
# паровой is ADJF
#   is None
# насос is NOUN
#  ( is None
# из is PREP
#   is None
# котел is NOUN
#  —  is None
# пара is NOUN
# ,  is None
# из is PREP
#   is None
# труба is NOUN
#  —  is None
# дым is NOUN
# ),  is None
# за is PREP
#   is None
# она is NPRO
#  —  is None
# медицинский is ADJF
#   is None
# фургон is NOUN
# ,  is None
# чтобы is CONJ
#   is None
# спасать is INFN
#   is None
# обжигать is INFN
# .  is None
# я is NPRO
#   is None
# плакать is INFN
# ,  is None
# и is CONJ
#   is None
# мама is NOUN
#   is None
# говорить is INFN
# ,  is None
# чтобы is CONJ
#   is None
# я is NPRO
#   is None
# не is PRCL
#   is None
# бояться is INFN
# ,  is None
# только is PRCL
#   is None
# ведь is CONJ
#   is None
# платить is INFN
#   is None
# я is NPRO
#   is None
# не is PRCL
#   is None
# от is PREP
#   is None
# страх is ADVB
#  —  is None
# от is PREP
#   is None
# избыток is NOUN
#   is None
# чувство is NOUN
# ,  is None
# от is PREP
#   is None
# восхищение is NOUN
#   is None
# мужество is NOUN
#   is None
# и is CONJ
#   is None
# великий is ADJF
#   is None
# слава is NOUN
#   is None
# этот is ADJF
#   is None
# человек is NOUN
# ,  is None
# оттого is ADVB
# ,  is None
# что is CONJ
#   is None
# так is CONJ
#   is None
# величественно is ADVB
#   is None
# они is NPRO
#   is None
# плыть is INFN
#   is None
# мимо is ADVB
#   is None
# замирать is INFN
#   is None
# толпа is NOUN
#   is None
# под is PREP
#   is None
# колокольный is ADJF
#   is None
# звон is NOUN
# . is None
#
#  is None
#
#  is None
# я is NPRO
#   is None
# очень is ADVB
#   is None
# хотеть is INFN
#   is None
# становиться is INFN
#   is None
# брандмейстер is NOUN
#   is None
# и is CONJ
#   is None
# всякий is ADJF
#   is None
# раз is NOUN
# ,  is None
# видеть is INFN
#   is None
# пожарный is ADJF
# ,  is None
# обращать is INFN
#   is None
# к is PREP
#   is None
# они is NPRO
#   is None
# беззвучный is ADJF
#   is None
# просьба is NOUN
#   is None
# принимать is INFN
#   is None
# я is NPRO
#   is None
# в is PREP
#   is None
# их is NPRO
#   is None
# ряд is NOUN
# .  is None
# она is NPRO
# ,  is None
# понятно is ADVB
# ,  is None
# не is PRCL
#   is None
# быть is INFN
#   is None
# услышать is INFN
# ,  is None
# но is CONJ
#   is None
# сейчас is ADVB
# ,  is None
# спустя is PREP
#   is None
# год is NOUN
# ,  is None
# я is NPRO
#   is None
# об is PREP
#   is None
# это is PRCL
#   is None
# не is PRCL
#   is None
# жалеть is INFN
# .  is None
# тогда is ADVB
#   is None
# же is PRCL
# ,  is None
# проезжать is INFN
#   is None
# по is PREP
#   is None
# невский is NOUN
#   is None
# на is PREP
#   is None
# империал is NOUN
# ,  is None
# я is NPRO
#   is None
# неизменно is ADVB
#   is None
# представлять is INFN
# ,  is None
# что is CONJ
#   is None
# направляться is INFN
#   is None
# на is PREP
#   is None
# пожар is NOUN
# :  is None
# держаться is INFN
#   is None
# торжественно is ADVB
#   is None
# и is CONJ
#   is None
# немного is ADVB
#   is None
# грустный is ADJF
# ,  is None
# и is CONJ
#   is None
# не is PRCL
#   is None
# знать is INFN
# ,  is None
# как is CONJ
#   is None
# там is ADVB
#   is None
# все is ADJF
#   is None
# еще is PRCL
#   is None
# складываться is INFN
#   is None
# при is PREP
#   is None
# тушение is NOUN
# ,  is None
# и is CONJ
#   is None
# ловить is INFN
#   is None
# восторженный is ADJF
#   is None
# взгляд is NOUN
# ,  is None
# и is CONJ
#   is None
# на is PREP
#   is None
# приветствие is NOUN
#   is None
# толпа is NOUN
# ,  is None
# слегка is ADVB
#   is None
# откинуть is INFN
#   is None
# голова is NOUN
#   is None
# набок is ADVB
# ,  is None
# отвечать is INFN
#   is None
# один is ADJF
#   is None
# глаз is NOUN
# . is None
#
#  is None

# %%
mystem.analyze(texts[0])
# Out:
# [{'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'профессорский'}],
#   'text': 'Профессорская'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'дача'}], 'text': 'дача'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(дат,ед|местн,ед)', 'lex': 'берег'}],
#   'text': 'берегу'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'финский'}],
#   'text': 'Финского'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'залив'}], 'text': 'залива'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'отсутствие'}],
#   'text': 'отсутствие'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=(вин,ед|род,ед)', 'lex': 'хозяин'}],
#   'text': 'хозяина'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,муж,од=(вин,ед|род,ед)', 'lex': 'друг'}],
#   'text': 'друга'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#     'lex': 'мой'}],
#   'text': 'моего'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=(вин,ед|род,ед)', 'lex': 'отец'}],
#   'text': 'отца'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#     'lex': 'наш'}],
#   'text': 'нашей'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'семья'}],
#   'text': 'семье'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,сред', 'lex': 'позволяться'}],
#   'text': 'позволялось'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADVPRO=', 'lex': 'там'}], 'text': 'там'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'жить'}], 'text': 'жить'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'даже'}], 'text': 'Даже'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'спустя'}], 'text': 'спустя'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)',
#     'lex': 'десятилетие'}],
#   'text': 'десятилетия'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'помнить'}],
#   'text': 'помню'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'после'}], 'text': 'после'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'утомительный'}],
#   'text': 'утомительной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'дорога'}],
#   'text': 'дороги'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'из'}], 'text': 'из'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'город'}],
#   'text': 'города'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=(вин|род)', 'lex': 'я'}], 'text': 'меня'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,жен,несов,пе', 'lex': 'обволакивать'}],
#   'text': 'обволакивала'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'прохлада'}],
#   'text': 'прохлада'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'деревянный'}],
#   'text': 'деревянного'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'дома'}], 'text': 'дома'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,жен,несов,пе', 'lex': 'собирать'}],
#   'text': 'собирала'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=(прош,вин,ед,прич,полн,сред,сов,действ|прош,им,ед,прич,полн,сред,сов,действ)',
#     'lex': 'растрясаться'}],
#   'text': 'растрясшееся'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,нп=(прош,вин,ед,прич,полн,сред,сов,действ|прош,им,ед,прич,полн,сред,сов,действ)',
#     'lex': 'распадаться'}],
#   'text': 'распавшееся'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'экипаж'}],
#   'text': 'экипаже'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'тело'}],
#   'text': 'тело'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'APRO=им,ед,жен', 'lex': 'этот'}], 'text': 'Эта'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'прохлада'}],
#   'text': 'прохлада'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,жен,несов', 'lex': 'быть'}],
#   'text': 'была'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=ед,кр,жен', 'lex': 'связанный'}], 'text': 'связана'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'со'}], 'text': 'со'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'свежесть'}],
#   'text': 'свежестью'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV=срав', 'lex': 'скоро'}], 'text': 'скорее'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'ни'}], 'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=ед,кр,сред', 'lex': 'странный'}], 'text': 'странно'},
#  {'text': ', — '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'упоительный'}],
#   'text': 'упоительной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'затхлость'}],
#   'text': 'затхлостью'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#     'lex': 'который'}],
#   'text': 'которой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,мн,изъяв,сов', 'lex': 'сливаться'}],
#   'text': 'слились'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'аромат'}],
#   'text': 'ароматы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'старый'}],
#   'text': 'старых'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=род,мн', 'lex': 'книга'}], 'text': 'книг'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'многочисленный'}],
#   'text': 'многочисленных'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'океанский'}],
#   'text': 'океанских'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'трофей'}],
#   'text': 'трофеев'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'непонятно'}], 'text': 'непонятно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=(прош,пр,мн,прич,полн,сов,действ|прош,род,мн,прич,полн,сов,действ|прош,вин,мн,прич,полн,сов,действ,од)',
#     'lex': 'доставаться'}],
#   'text': 'доставшихся'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=дат,ед', 'lex': 'профессор'}],
#   'text': 'профессору'},
#  {'text': '-'},
#  {'analysis': [{'gr': 'S,муж,од=дат,ед', 'lex': 'юрист'}], 'text': 'юристу'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V,пе=непрош,деепр,несов', 'lex': 'распространять'}],
#   'text': 'Распространяя'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'солоноватый'}],
#   'text': 'солоноватый'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'запах'}],
#   'text': 'запах'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=пр,мн', 'lex': 'полка'}], 'text': 'полках'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,мн,изъяв', 'lex': 'лежать'}],
#   'text': 'лежали'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=(прош,вин,мн,прич,полн,сов,страд,неод|прош,им,мн,прич,полн,сов,страд)',
#     'lex': 'засушивать'}],
#   'text': 'засушенные'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A,полн=(им,мн|вин,мн,неод)', 'lex': 'морской'}],
#   'text': 'морские'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'звезда'}],
#   'text': 'звёзды'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'A=(вин,мн,полн,неод|им,мн,полн)',
#     'lex': 'перламутровый'}],
#   'text': 'перламутровые'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'раковина'}],
#   'text': 'раковины'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'A=(вин,мн,полн,неод|им,мн,полн)', 'lex': 'резной'}],
#   'text': 'резные'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'маска'}],
#   'text': 'маски'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'пробковый'}],
#   'text': 'пробковый'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'шлем'}],
#   'text': 'шлем'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'даже'}], 'text': 'даже'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'игла'}], 'text': 'игла'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,од=(род,ед|им,мн)', 'lex': 'рыба'}],
#   'text': 'рыбы'},
#  {'text': '-'},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'игла'}],
#   'text': 'иглы'},
#  {'text': '.'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'аккуратно'}], 'text': 'Аккуратно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=непрош,деепр,несов', 'lex': 'отодвигать'}],
#   'text': 'отодвигая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'дар'}],
#   'text': 'дары'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'lex': 'море'}],
#   'text': 'моря'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=прош,ед,изъяв,муж,несов', 'lex': 'доставать'}],
#   'text': 'доставал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=род,мн', 'lex': 'полка'}], 'text': 'полок'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'книга'}],
#   'text': 'книги'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'садиться'}],
#   'text': 'садился'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'по-турецки'}], 'text': 'по-турецки'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'кресло'}],
#   'text': 'кресло'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=твор,мн,полн', 'lex': 'самшитовый'}],
#   'text': 'самшитовыми'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=твор,мн', 'lex': 'подлокотник'}],
#   'text': 'подлокотниками'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,ед,изъяв,муж', 'lex': 'читать'}],
#   'text': 'читал'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,ед,изъяв,муж', 'lex': 'листать'}],
#   'text': 'Листал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'страница'}],
#   'text': 'страницы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'правый'}],
#   'text': 'правой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'рука'}], 'text': 'рукой'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'левый'}], 'text': 'левая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,жен,несов,пе', 'lex': 'сжимать'}],
#   'text': 'сжимала'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'кусок'}],
#   'text': 'кусок'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'хлеб'}],
#   'text': 'хлеба'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'масло'}],
#   'text': 'маслом'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=твор,ед', 'lex': 'сахар'}],
#   'text': 'сахаром'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,муж,несов,пе', 'lex': 'откусывать'}],
#   'text': 'Откусывал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'задумчиво'}], 'text': 'задумчиво'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,ед,изъяв,муж', 'lex': 'читать'}],
#   'text': 'читал'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'сахар'}],
#   'text': 'сахар'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж', 'lex': 'скрипеть'}],
#   'text': 'скрипел'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)', 'lex': 'мой'}],
#   'text': 'моих'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=пр,мн', 'lex': 'зуб'}], 'text': 'зубах'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(вин|им)', 'lex': 'это'}],
#   'text': 'Это'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,мн,изъяв,несов', 'lex': 'быть'}],
#   'text': 'были'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,имя,муж,од=им,ед', 'lex': 'жюль'}], 'text': 'жюль'},
#  {'text': '-'},
#  {'analysis': [{'gr': 'S,фам,муж,од=им,мн',
#     'lex': 'верновский',
#     'qual': 'bastard'}],
#   'text': 'верновские'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'роман'}],
#   'text': 'романы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'или'}], 'text': 'или'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,мн,полн,неод|им,мн,полн)', 'lex': 'журнальный'}],
#   'text': 'журнальные'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V=(прош,вин,мн,прич,полн,сов,страд,неод|прош,им,мн,прич,полн,сов,страд)',
#     'lex': 'переплетать'}],
#   'text': 'переплетённые'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'кожа'}], 'text': 'кожу'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'lex': 'описание'}],
#   'text': 'описания'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'экзотический'}],
#   'text': 'экзотических'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=род,мн', 'lex': 'страна'}], 'text': 'стран'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'мир'}],
#   'text': 'мир'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'неведомый'}],
#   'text': 'неведомый'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'недоступный'}],
#   'text': 'недоступный'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#     'lex': 'юриспруденция'}],
#   'text': 'юриспруденции'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'бесконечно'}], 'text': 'бесконечно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'далекий'}],
#   'text': 'далёкий'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'На'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#     'lex': 'свой'}],
#   'text': 'своей'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'дача'}],
#   'text': 'даче'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=им,ед', 'lex': 'профессор'}],
#   'text': 'профессор'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,муж,сов', 'lex': 'собирать'}],
#   'text': 'собрал'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'очевидно'}], 'text': 'очевидно'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'то'}], 'text': 'то'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(пр|твор)', 'lex': 'что'}],
#   'text': 'чём'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,муж=дат', 'lex': 'он'}], 'text': 'ему'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,сред', 'lex': 'мечтаться'}],
#   'text': 'мечталось'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'lex': 'детство'}],
#   'text': 'детства'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'что'}], 'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,сред',
#     'lex': 'предусматриваться'}],
#   'text': 'предусматривалось'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)',
#     'lex': 'его'}],
#   'text': 'его'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#     'lex': 'нынешний'}],
#   'text': 'нынешним'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'положение'}],
#   'text': 'положением'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,сред',
#     'lex': 'регулироваться'}],
#   'text': 'регулировалось'},
#  {'text': ' «'},
#  {'analysis': [{'gr': 'S,муж,неод=твор,ед', 'lex': 'свод'}], 'text': 'Сводом'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'закон'}],
#   'text': 'законов'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'российский'}],
#   'text': 'Российской'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#     'lex': 'империя'}],
#   'text': 'империи'},
#  {'text': '»'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'милый'}],
#   'text': 'милых'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)',
#     'lex': 'его'}],
#   'text': 'его'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=дат,ед', 'lex': 'сердце'}],
#   'text': 'сердцу'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=пр,мн', 'lex': 'страна'}],
#   'text': 'странах'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'закон'}],
#   'text': 'законов'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'подозревать'}],
#   'text': 'подозреваю'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,сред,несов', 'lex': 'быть'}],
#   'text': 'было'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'вообще'}], 'text': 'вообще'},
#  {'text': '.'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'время'}],
#   'text': 'Время'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(пр,ед|дат,ед|род,ед)', 'lex': 'время'}],
#   'text': 'времени'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,муж,несов,пе', 'lex': 'подымать'}],
#   'text': 'поднимал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'глаз'}],
#   'text': 'глаза'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'книга'}],
#   'text': 'книги'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,деепр', 'lex': 'наблюдать'}],
#   'text': 'наблюдая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'угасание'}],
#   'text': 'угасание'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'залив'}], 'text': 'залива'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'за'}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'окно'}], 'text': 'окном'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж', 'lex': 'пытаться'}],
#   'text': 'пытался'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=инф,сов', 'lex': 'понимать'}], 'text': 'понять'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=непрош,мн,изъяв,3-л,несов', 'lex': 'становиться'}],
#   'text': 'становятся'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=твор,мн', 'lex': 'юрист'}],
#   'text': 'юристами'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,мн,изъяв,3-л', 'lex': 'мечтать'}],
#   'text': 'Мечтают'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'об'}], 'text': 'об'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=пр', 'lex': 'это'}], 'text': 'этом'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'lex': 'детство'}],
#   'text': 'детства'},
#  {'text': '? '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'сомнительно'}], 'text': 'Сомнительно'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=пр,ед', 'lex': 'детство'}],
#   'text': 'детстве'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж', 'lex': 'мечтать'}],
#   'text': 'мечтал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=инф,несов', 'lex': 'быть'}], 'text': 'быть'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=твор,ед', 'lex': 'дирижер'}],
#   'text': 'дирижёром'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'или'}], 'text': 'или'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'скажем'}], 'text': 'скажем'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,муж,од=твор,ед', 'lex': 'брандмейстер'}],
#   'text': 'брандмейстером'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=твор,ед', 'lex': 'юрист'}], 'text': 'юристом'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'ADVPRO=', 'lex': 'никогда'}], 'text': 'никогда'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'еще'}], 'text': 'Ещё'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=прош,ед,изъяв,муж,несов', 'lex': 'представлять'}],
#   'text': 'представлял'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO=(пр|дат)', 'lex': 'себя'}], 'text': 'себе'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'будто'}], 'text': 'будто'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,сов', 'lex': 'оставаться'}],
#   'text': 'остался'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#     'lex': 'этот'}],
#   'text': 'этой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'прохладный'}],
#   'text': 'прохладной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'комната'}],
#   'text': 'комнате'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'навеки'}], 'text': 'навеки'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,1-л', 'lex': 'жить'}],
#   'text': 'живу'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,жен=(пр|дат|род|твор)', 'lex': 'она'}],
#   'text': 'ней'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'капсула'}],
#   'text': 'капсуле'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'за'}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'окно'}], 'text': 'окном'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'перемена'}],
#   'text': 'перемены'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'переворот'}],
#   'text': 'перевороты'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)',
#     'lex': 'землетрясение'}],
#   'text': 'землетрясения'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'нет'}], 'text': 'нет'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADVPRO=', 'lex': 'там'}], 'text': 'там'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'больше'}], 'text': 'больше'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'ни'}], 'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'сахар'}],
#   'text': 'сахара'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'ни'}], 'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'lex': 'масло'}],
#   'text': 'масла'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'ни'}], 'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'даже'}], 'text': 'даже'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'российский'}],
#   'text': 'Российской'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#     'lex': 'империя'}],
#   'text': 'империи'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'только'}], 'text': 'только'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,мн=(вин|им)', 'lex': 'все'}], 'text': 'всё'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,1-л', 'lex': 'сидеть'}],
#   'text': 'сижу'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'читать'}],
#   'text': 'читаю'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'читать'}],
#   'text': 'читаю'},
#  {'text': '… '},
#  {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'дальнейший'}],
#   'text': 'Дальнейшая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,ед|им,ед)', 'lex': 'жизнь'}],
#   'text': 'жизнь'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V=прош,ед,изъяв,жен,сов', 'lex': 'показывать'}],
#   'text': 'показала'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'что'}], 'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=твор,ед', 'lex': 'сахар'}],
#   'text': 'сахаром'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'масло'}],
#   'text': 'маслом'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=прош,ед,изъяв,муж,сов', 'lex': 'угадывать'}],
#   'text': 'угадал'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'вот'}], 'text': 'вот'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'сидеть'}], 'text': 'сидеть'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'читать'}], 'text': 'читать'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'это'}],
#   'text': 'этого'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'INTJ=', 'lex': 'увы'}], 'text': 'увы'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,сред,сов', 'lex': 'получаться'}],
#   'text': 'получилось'},
#  {'text': '.'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'gr': 'SPRO,мн,1-л=им', 'lex': 'мы'}], 'text': 'Мы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)',
#     'lex': 'полежаевский',
#     'qual': 'bastard'}],
#   'text': 'Полежаевском'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'парк'}], 'text': 'парке'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'середина'}],
#   'text': 'середина'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'июнь'}], 'text': 'июня'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'ADVPRO=', 'lex': 'там'}], 'text': 'Там'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'течь'}],
#   'text': 'течет'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'речка'}], 'text': 'речка'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,од=им,ед', 'lex': 'лиговка', 'qual': 'bastard'}],
#   'text': 'Лиговка'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,жен=им', 'lex': 'она'}], 'text': 'она'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'небольшой'}],
#   'text': 'небольшая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'совсем'}], 'text': 'совсем'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'парк'}], 'text': 'парке'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов',
#     'lex': 'превращаться'}],
#   'text': 'превращается'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'озеро'}],
#   'text': 'озеро'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'На'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'вода'}],
#   'text': 'воде'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'лодка'}],
#   'text': 'лодки'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'трава'}],
#   'text': 'траве'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'A=(вин,мн,полн,неод|им,мн,полн)', 'lex': 'клетчатый'}],
#   'text': 'клетчатые'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'плед'}],
#   'text': 'пледы'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#     'lex': 'скатерть'}],
#   'text': 'скатерти'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'бахрома'}],
#   'text': 'бахромой'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'самовар'}],
#   'text': 'самовары'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'Я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'наблюдать'}],
#   'text': 'наблюдаю'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'за'}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=твор', 'lex': 'то'}], 'text': 'тем'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'компания'}],
#   'text': 'компания'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,им,ед,прич,полн,жен,действ',
#     'lex': 'сидеть'}],
#   'text': 'сидящая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'неподалеку'}], 'text': 'неподалеку'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V=непрош,ед,изъяв,3-л,несов,пе', 'lex': 'заводить'}],
#   'text': 'заводит'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'патефон'}],
#   'text': 'патефон'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'SPRO,ед,муж,од=им', 'lex': 'кто'}], 'text': 'Кто'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'именно'}], 'text': 'именно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'сидеть'}],
#   'text': 'сидит'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'уже'}], 'text': 'уже'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'помнить'}],
#   'text': 'помню'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,мн=(вин|им)', 'lex': 'все'}], 'text': 'всё'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'еще'}], 'text': 'еще'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'видеть'}],
#   'text': 'вижу'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'вращаться'}],
#   'text': 'вращается'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'ручка'}], 'text': 'ручка'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'через'}], 'text': 'Через'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'мгновение'}],
#   'text': 'мгновение'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов', 'lex': 'раздаваться'}],
#   'text': 'раздается'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'музыка'}], 'text': 'музыка'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'хриплый'}],
#   'text': 'хриплая'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,нп=непрош,им,ед,прич,полн,жен,несов,действ',
#     'lex': 'заикаться'}],
#   'text': 'заикающаяся'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'все'}], 'text': 'всё'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'же'}], 'text': 'же'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'музыка'}], 'text': 'музыка'},
#  {'text': '.'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'ящик'}],
#   'text': 'Ящик'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'полный'}],
#   'text': 'полный'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'маленький'}],
#   'text': 'маленьких'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V=(прош,пр,мн,прич,полн,сов,страд,пе|прош,вин,мн,прич,полн,сов,страд,од,пе|прош,род,мн,прич,полн,сов,страд,пе)',
#     'lex': 'простужать'}],
#   'text': 'простуженных'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=(непрош,пр,мн,прич,полн,действ|непрош,род,мн,прич,полн,действ|непрош,вин,мн,прич,полн,действ,од)',
#     'lex': 'петь'}],
#   'text': 'поющих'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'пусть'}], 'text': 'пусть'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'извне'}], 'text': 'извне'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#     'lex': 'невидимый'}],
#   'text': 'невидимых'},
#  {'text': ', — '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'у'}], 'text': 'у'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=(вин|род)', 'lex': 'я'}], 'text': 'меня'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#     'lex': 'такой'}],
#   'text': 'такого'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,сред,несов', 'lex': 'быть'}],
#   'text': 'было'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'И'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADVPRO=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'же'}], 'text': 'же'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,ед,изъяв,муж', 'lex': 'хотеть'}],
#   'text': 'хотел'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,мн=дат', 'lex': 'они'}], 'text': 'им'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'обладать'}],
#   'text': 'обладать'},
#  {'text': ': '},
#  {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'заботиться'}],
#   'text': 'заботиться'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,муж=пр', 'lex': 'он'}], 'text': 'нём'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'лелеять'}], 'text': 'лелеять'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'ставить'}], 'text': 'ставить'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'зима'}], 'text': 'зимой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'у'}], 'text': 'у'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн|местн,ед)',
#     'lex': 'печь'}],
#   'text': 'печи'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'главное'}], 'text': 'главное'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'V=инф,несов,пе', 'lex': 'заводить'}],
#   'text': 'заводить'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,муж=(вин|род)', 'lex': 'он'}],
#   'text': 'его'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'царственный'}],
#   'text': 'царственной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'небрежность'}],
#   'text': 'небрежностью'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,мн,изъяв,3-л', 'lex': 'делать'}],
#   'text': 'делают'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,ед|им,ед)', 'lex': 'вещь'}],
#   'text': 'вещь'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'давно'}], 'text': 'давно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=вин,ед,полн,жен', 'lex': 'привычный'}],
#   'text': 'привычную'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'S,сред,неод=(вин,ед|им,ед)', 'lex': 'вращение'}],
#   'text': 'Вращение'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'ручка'}],
#   'text': 'ручки'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,сред', 'lex': 'казаться'}],
#   'text': 'казалось'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=(пр|дат)', 'lex': 'я'}], 'text': 'мне'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'простой'}],
#   'text': 'простой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'одновременно'}], 'text': 'одновременно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A,полн=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#     'lex': 'неочевидный'}],
#   'text': 'неочевидной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'причина'}],
#   'text': 'причиной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=(непрош,пр,мн,прич,полн,действ|непрош,род,мн,прич,полн,действ|непрош,вин,мн,прич,полн,действ,од)',
#     'lex': 'литься'}],
#   'text': 'льющихся'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'звук'}], 'text': 'звуков'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#     'lex': 'свой'}],
#   'text': 'своего'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'род'}],
#   'text': 'рода'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'универсальный'}],
#   'text': 'универсальной'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'отмычка'}],
#   'text': 'отмычкой'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'к'}], 'text': 'к'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(дат,ед,полн,муж|дат,ед,полн,сред)',
#     'lex': 'прекрасный'}],
#   'text': 'прекрасному'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,сред,несов', 'lex': 'быть'}],
#   'text': 'Было'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=пр', 'lex': 'это'}], 'text': 'этом'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(вин|им)', 'lex': 'что-то'}],
#   'text': 'что-то'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#     'lex': 'моцартовский',
#     'qual': 'bastard'}],
#   'text': 'моцартовское'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(вин|им)', 'lex': 'что-то'}],
#   'text': 'что-то'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'взмах'}], 'text': 'взмаха'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'дирижерский'}],
#   'text': 'дирижерской'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'lex': 'палочка'}],
#   'text': 'палочки'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,пе=(непрош,вин,ед,прич,полн,муж,несов,действ,од|непрош,род,ед,прич,полн,муж,несов,действ|непрош,род,ед,прич,полн,сред,несов,действ)',
#     'lex': 'оживлять'}],
#   'text': 'оживляющего'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,мн,полн,неод|им,мн,полн)', 'lex': 'немой'}],
#   'text': 'немые'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|им,мн)', 'lex': 'инструмент'}],
#   'text': 'инструменты'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=твор,мн,полн', 'lex': 'земной'}], 'text': 'земными'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=твор,мн', 'lex': 'закон'}],
#   'text': 'законами'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'также'}], 'text': 'также'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'вполне'}], 'text': 'вполне'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'объяснимый'}],
#   'text': 'объяснимого'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'Я'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'бывало'}], 'text': 'бывало'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж', 'lex': 'дирижировать'}],
#   'text': 'дирижировал'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'наедине'}], 'text': 'наедине'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO=твор', 'lex': 'себя'}], 'text': 'собой'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'V,пе=непрош,деепр,несов', 'lex': 'напевать'}],
#   'text': 'напевая'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,сов,пе=(прош,вин,мн,прич,полн,страд,неод|прош,им,мн,прич,полн,страд)',
#     'lex': 'услышать'}],
#   'text': 'услышанные'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#     'lex': 'мелодия'}],
#   'text': 'мелодии'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'неплохо'}], 'text': 'неплохо'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'у'}], 'text': 'у'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=(вин|род)', 'lex': 'я'}], 'text': 'меня'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,сред,несов', 'lex': 'получаться'}],
#   'text': 'получалось'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'если'}], 'text': 'Если'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'бы'}], 'text': 'бы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'мечта'}], 'text': 'мечта'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=инф,сов', 'lex': 'становиться'}], 'text': 'стать'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=твор,ед', 'lex': 'брандмейстер'}],
#   'text': 'брандмейстером'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'то'}], 'text': 'то'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,ед,изъяв,муж', 'lex': 'хотеть'}],
#   'text': 'хотел'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'бы'}], 'text': 'бы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=инф,несов', 'lex': 'быть'}], 'text': 'быть'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'конечно'}], 'text': 'конечно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'же'}], 'text': 'же'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'S,муж,од=твор,ед', 'lex': 'дирижер'}],
#   'text': 'дирижером'},
#  {'text': '.'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)', 'lex': 'тот'}],
#   'text': 'тот'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'июньский'}],
#   'text': 'июньский'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'день'}],
#   'text': 'день'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,мн,1-л=им', 'lex': 'мы'}], 'text': 'мы'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,мн,изъяв', 'lex': 'видеть'}],
#   'text': 'видели'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,од=(вин,ед|род,ед)', 'lex': 'дирижер'}],
#   'text': 'дирижера'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'С'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#     'lex': 'послушный'}],
#   'text': 'послушным'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)',
#     'lex': 'его'}],
#   'text': 'его'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'рука'}],
#   'text': 'руке'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=твор,ед', 'lex': 'оркестр'}],
#   'text': 'оркестром'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,3-л,муж=им', 'lex': 'он'}], 'text': 'он'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'потихоньку'}], 'text': 'потихоньку'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'удаляться'}],
#   'text': 'удалялся'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'lex': 'берег'}],
#   'text': 'берега'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'Не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'парковый'}],
#   'text': 'парковый'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'быть'}],
#   'text': 'был'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)', 'lex': 'оркестр'}],
#   'text': 'оркестр'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#     'lex': 'духовой'}],
#   'text': 'духовой'},
#  {'text': ' — '},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#     'lex': 'симфонический'}],
#   'text': 'симфонический'},
#  {'text': '. '},
#  {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж', 'lex': 'стоять'}],
#   'text': 'Стоял'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,муж,неод=(дат,ед|местн,ед)', 'lex': 'плот'}],
#   'text': 'плоту'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'непонятно'}], 'text': 'непонятно'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,деепр,сов', 'lex': 'помещаться'}],
#   'text': 'поместившись'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PR=', 'lex': 'по'}], 'text': 'по'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=(пр,ед|дат,ед)', 'lex': 'вода'}],
#   'text': 'воде'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,жен,несов', 'lex': 'растекаться'}],
#   'text': 'растекалась'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)',
#     'lex': 'его'}],
#   'text': 'его'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'музыка'}], 'text': 'музыка'},
#  {'text': ', '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)',
#     'lex': 'ее'}],
#   'text': 'ее'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'ADV=', 'lex': 'вполуха'}], 'text': 'вполуха'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=прош,мн,изъяв', 'lex': 'слушать'}],
#   'text': 'слушали'},
#  ...]

# %%
x = pymorphy.parse('1917')[0]

# %%
x
# Out:
# Parse(word='1917', tag=OpencorporaTag('NUMB,intg'), normal_form='1917', score=1.0, methods_stack=((<NumberAnalyzer>, '1917'),))
